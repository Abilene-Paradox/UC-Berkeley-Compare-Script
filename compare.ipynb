# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
# read the files
df1 = pd.read_excel("R_T_44_21_48_1st-Key (1).xlsx")
df2 = pd.read_excel("R_T_44_21_48_2nd_key (1).xlsx")

# %%
# checl the shape
print("df1 shape", df1.shape)
print("df2 shape", df2.shape)
# Out:
# df1 shape (1102, 18)
# df2 shape (1103, 18)

# %%
df1["Number"] = df1.index
df2["Number"] = df2.index

# %%
# Remove the index columns
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)

# %%
# check the shape of df1
df1.shape
# Out:
# (1102, 19)

# %%
# check the shape of df2
df2.shape
# Out:
# (1103, 19)

# %%
# Highlighting the difference between two DataFrames
df_all = pd.concat([df1.set_index("Number"), df2.set_index("Number")], axis="columns", keys=["T_44_21_48_1st_key", "T_44_21_48_2nd_key"])
df_final = df_all.swaplevel(axis="columns")[df1.columns.drop('Number')[:]]
df_final
# Out:
#                     Photo                                 Folder
#        T_44_22_49_1st_key T_44_22_49 _2nd_key T_44_22_49_1st_key
# Number
# 0                IMG_6902            IMG_6902            T_44_22  \
# 1                     NaN                 NaN                NaN
# 2                IMG_6903            IMG_6903            T_44_22
# 3                     NaN                 NaN                NaN
# 4                IMG_6904            IMG_6904            T_44_22
# ...                   ...                 ...                ...
# 1098             IMG_6910            IMG_6910            T_44_22
# 1099             IMG_6910            IMG_6910            T_44_22
# 1100                  NaN            IMG_6910                NaN
# 1101             IMG_6911            IMG_6910            T_44_22
# 1102                  NaN            IMG_6911                NaN
#
#                                    Sub_Folder
# ...

# %%
pip install --upgrade pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def highlight_diff(data, color='red'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('T_44_21_48_1st_key', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

x = df_final.style.apply(highlight_diff, axis=None)
# print(type(x))
x.to_excel("Compared_T_44_21_48.xlsx")
